# %%
# import essential libraries
import pandas as pd
import numpy as np
import pickle
import scipy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression, LogisticRegressionCV, SGDClassifier, RidgeClassifier
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error, f1_score
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn import svm, linear_model
from sklearn import tree, metrics
from sklearn.metrics import classification_report

from sklearn.preprocessing import LabelEncoder
import lightgbm
from bayes_opt import BayesianOptimization
from catboost import CatBoostClassifier, cv, Pool
import gzip

# %%
# read in csv
df = pd.read_csv('data/training_25_features.csv')
df
# Out:
#              I     II    III    aVF    aVR    aVL     V1     V2     V3     V4  \
# 0       -0.005  0.135  0.140 -0.065 -0.073  0.137 -0.125 -0.090 -0.110 -0.210
# 1       -0.005  0.135  0.140 -0.065 -0.073  0.137 -0.125 -0.090 -0.110 -0.211
# 2       -0.005  0.131  0.136 -0.063 -0.070  0.133 -0.125 -0.082 -0.102 -0.190
# 3       -0.005  0.130  0.135 -0.063 -0.070  0.132 -0.122 -0.077 -0.094 -0.172
# 4       -0.005  0.128  0.133 -0.062 -0.069  0.130 -0.119 -0.071 -0.084 -0.157
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4319171  0.010  0.170  0.160 -0.090 -0.075  0.165  0.155  0.365  0.230  0.030
# 4319172  0.014  0.174  0.160 -0.094 -0.073  0.167  0.155  0.368  0.245  0.029
# 4319173  0.016  0.176  0.160 -0.096 -0.073  0.167  0.155  0.383  0.261  0.040
# 4319174  0.014  0.174  0.160 -0.094 -0.073  0.167  0.155  0.406  0.282  0.059
# 4319175  0.016  0.176  0.160 -0.096 -0.072  0.168  0.156  0.424  0.304  0.072
#
#          ...     weight  nurse  site  device  heart_axis  validated_by  \
# 0        ...  69.841845    0.0   0.0       0         3.0           0.0
# 1        ...  69.841845    0.0   0.0       0         3.0           0.0
# 2        ...  69.841845    0.0   0.0       0         3.0           0.0
# 3        ...  69.841845    0.0   0.0       0         3.0           0.0
# 4        ...  69.841845    0.0   0.0       0         3.0           0.0
# ...      ...        ...    ...   ...     ...         ...           ...
# 4319171  ...  69.841845    1.0   2.0       1         3.0           1.0
# 4319172  ...  69.841845    1.0   2.0       1         3.0           1.0
# 4319173  ...  69.841845    1.0   2.0       1         3.0           1.0
# 4319174  ...  69.841845    1.0   2.0       1         3.0           1.0
# 4319175  ...  69.841845    1.0   2.0       1         3.0           1.0
#
#          second_opinion  validated_by_human  pacemaker  strat_fold
# 0                     0                   0        0.0           6
# 1                     0                   0        0.0           6
# 2                     0                   0        0.0           6
# 3                     0                   0        0.0           6
# 4                     0                   0        0.0           6
# ...                 ...                 ...        ...         ...
# 4319171               0                   1        0.0           8
# 4319172               0                   1        0.0           8
# 4319173               0                   1        0.0           8
# 4319174               0                   1        0.0           8
# 4319175               0                   1        0.0           8
#
# [4319176 rows x 26 columns]

# %%
# convert all the columns to float64
# df = df.drop(['nurse','site','strat_fold'],axis='columns')

for i in range(23):
    df[df.columns[i]] = df[df.columns[i]].astype('float64')
    
# get info for columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4319176 entries, 0 to 4319175
# Data columns (total 26 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   I                   float64
#  1   II                  float64
#  2   III                 float64
#  3   aVF                 float64
#  4   aVR                 float64
#  5   aVL                 float64
#  6   V1                  float64
#  7   V2                  float64
#  8   V3                  float64
#  9   V4                  float64
#  10  V5                  float64
#  11  V6                  float64
#  12  ritmi               float64
#  13  age                 float64
#  14  sex                 float64
#  15  height              float64
#  16  weight              float64
#  17  nurse               float64
#  18  site                float64
#  19  device              float64
#  20  heart_axis          float64
#  21  validated_by        float64
#  22  second_opinion      float64
#  23  validated_by_human  int64
#  24  pacemaker           float64
#  25  strat_fold          int64
# dtypes: float64(24), int64(2)
# memory usage: 856.8 MB

# %%
# train-test split
X = df.drop(columns='ritmi')
y = df['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)

# %% [markdown]
# # KNN

# %%
clfl2 = KNeighborsClassifier()
parameters = {'n_neighbors': [140], 'weights': ['distance'], 'metric': ['euclidean']} #0.975402556683289

fitmodel = GridSearchCV(clfl2, param_grid=parameters, cv=5, refit=True, scoring="accuracy", n_jobs=-1, verbose=2)
fitmodel.fit(X_train, y_train)

print(fitmodel.best_estimator_, fitmodel.best_params_, fitmodel.best_score_)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# KNeighborsClassifier(metric='euclidean', n_neighbors=140, weights='distance') {'metric': 'euclidean', 'n_neighbors': 140, 'weights': 'distance'} 0.9754502556683289

# %%
import pickle as pkl
pkl.dump(fitmodel, open('ECG&patient_KNN.pkl', 'wb'))

# %%
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98    335792
#          1.0       0.96      0.97      0.97    267846
#          2.0       0.98      0.98      0.98    476156
#
#     accuracy                           0.98   1079794
#    macro avg       0.98      0.98      0.98   1079794
# weighted avg       0.98      0.98      0.98   1079794

# %% [markdown]
# # XGboost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
estimator = XGBClassifier(
    objective= 'multi:softmax',
    num_class=3,
    nthread=4,
    seed=42
)
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}
grid_search = GridSearchCV(
    estimator=estimator,
    param_grid=parameters,
    scoring = 'roc_auc',
    n_jobs = -1,
    cv = 5,
    verbose=4
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits

# %%
print(grid_search.best_estimator_, grid_search.best_params_, grid_search.best_score_)

# %% [markdown]
# # Dask implementation

# %%
from dask_kubernetes import KubeCluster
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_22888\754908373.py:1: DeprecationWarning: It looks like you are using the classic implementation of KubeCluster. Please consider migrating to the new operator based implementation https://kubernetes.dask.org/en/latest/kubecluster_migrating.html. To suppress this warning import KubeCluster directly from dask_kubernetes.classic. But note this will be removed in the future.
#   from dask_kubernetes import KubeCluster

# %%
client = Client(n_workers = 4, threads_per_worker = 1, memory_limit = '4GB')

# %%
from dask.distributed import Client,progress
c= Client(n_workers = 4, threads_per_worker = 1, memory_limit = '3GB')
c
# Out:
# <Client: 'tcp://127.0.0.1:56502' processes=4 threads=4, memory=11.18 GiB>

# %%
import dask.dataframe as dd
data = dd.read_csv('data/training_25_features.csv')
data = data.persist()
progress(data)
# Out:
# VBox()

# %%
data
# Out:
# Dask DataFrame Structure:
#                      I       II      III      aVF      aVR      aVL       V1       V2       V3       V4       V5       V6  ritmi      age    sex   height   weight    nurse     site device heart_axis validated_by second_opinion validated_by_human pacemaker strat_fold
# npartitions=9
#                float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  int64  float64  int64  float64  float64  float64  float64  int64    float64      float64          int64              int64   float64      int64
#                    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...      ...    ...      ...      ...      ...      ...    ...        ...          ...            ...                ...       ...        ...
# ...                ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...      ...    ...      ...      ...      ...      ...    ...        ...          ...            ...                ...       ...        ...
#                    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...      ...    ...      ...      ...      ...      ...    ...        ...          ...            ...                ...       ...        ...
#                    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...      ...    ...      ...      ...      ...      ...    ...        ...          ...            ...                ...       ...        ...
# Dask Name: read-csv, 1 graph layer

# %%
data.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 26 entries, I to strat_fold
# dtypes: float64(24), int64(2)

# %%
# convert all the columns to float64
# df = df.drop(['nurse','site','strat_fold'],axis='columns')
df=data
for i in range(23):
    df[df.columns[i]] = df[df.columns[i]].astype('float64')
    
# get info for columns
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 26 entries, I to strat_fold
# dtypes: float64(24), int64(2)

# %%
# train-test split
X = df.drop(columns='ritmi')
y = df['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       2 X = df.drop(columns='ritmi')
#       3 y = df['ritmi']
# ----> 4 X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_split.py:2471, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2467     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2469     train, test = next(cv.split(X=arrays[0], y=stratify))
# -> 2471 return list(
#    2472     chain.from_iterable(
#    2473         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2474     )
#    2475 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_split.py:2473, in <genexpr>(.0)
#    2467     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2469     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2471 return list(
#    2472     chain.from_iterable(
# -> 2473         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2474     )
#    2475 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\__init__.py:359, in _safe_indexing(X, indices, axis)
#     353     raise ValueError(
#     354         "Specifying the columns using strings is only supported for "
#     355         "pandas DataFrames"
#     356     )
#     358 if hasattr(X, "iloc"):
# --> 359     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     360 elif hasattr(X, "shape"):
#     361     return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\__init__.py:201, in _pandas_indexing(X, key, key_dtype, axis)
#     196     key = list(key)
#     198 if key_dtype == "int" and not (isinstance(key, slice) or np.isscalar(key)):
#     199     # using take() instead of iloc[] ensures the return value is a "proper"
#     200     # copy that will not raise SettingWithCopyWarning
# --> 201     return X.take(key, axis=axis)
#     202 else:
#     203     # check whether we should index with loc or iloc
#     204     indexer = X.iloc if key_dtype == "int" else X.loc
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dask\dataframe\core.py:4684, in DataFrame.__getattr__(self, key)
#    4682     object.__getattribute__(self, key)
#    4683 else:
# -> 4684     raise AttributeError("'DataFrame' object has no attribute %r" % key)
#
# AttributeError: 'DataFrame' object has no attribute 'take'

# %%
import joblib
from sklearn.ensemble import RandomForestClassifier
import dask_ml

# %%
cluster = KubeCluster(n_workers=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 cluster = KubeCluster(n_workers=30)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dask_kubernetes\classic\kubecluster.py:503, in KubeCluster.__init__(self, pod_template, name, namespace, n_workers, host, port, env, auth, idle_timeout, deploy_mode, interface, protocol, dashboard_address, security, scheduler_service_wait_timeout, scheduler_service_name_resolution_retries, scheduler_pod_template, apply_default_affinity, **kwargs)
#     501 self.auth = auth
#     502 self.kwargs = kwargs
# --> 503 super().__init__(**self.kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\distributed\deploy\spec.py:275, in SpecCluster.__init__(self, workers, scheduler, worker, asynchronous, loop, security, silence_logs, name, shutdown_on_close, scheduler_sync_interval)
#     273 if not called_from_running_loop:
#     274     self._loop_runner.start()
# --> 275     self.sync(self._start)
#     276     try:
#     277         self.sync(self._correct_state)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\distributed\utils.py:339, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     337     return future
#     338 else:
# --> 339     return sync(
#     340         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     341     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\distributed\utils.py:406, in sync(loop, func, callback_timeout, *args, **kwargs)
#     404 if error:
#     405     typ, exc, tb = error
# --> 406     raise exc.with_traceback(tb)
#     407 else:
#     408     return result
#
# File ~\AppData\Roaming\Python\Python39\site-packages\distributed\utils.py:379, in sync.<locals>.f()
#     377         future = asyncio.wait_for(future, callback_timeout)
#     378     future = asyncio.ensure_future(future)
# --> 379     result = yield future
#     380 except Exception:
#     381     error = sys.exc_info()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tornado\gen.py:762, in Runner.run(self)
#     759 exc_info = None
#     761 try:
# --> 762     value = future.result()
#     763 except Exception:
#     764     exc_info = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dask_kubernetes\classic\kubecluster.py:563, in KubeCluster._start(self)
#     558 if not self.pod_template:
#     559     msg = (
#     560         "Worker pod specification not provided. See KubeCluster "
#     561         "docstring for ways to specify workers"
#     562     )
# --> 563     raise ValueError(msg)
#     565 base_pod_template = self.pod_template
#     566 self.pod_template = clean_pod_template(
#     567     self.pod_template,
#     568     apply_default_affinity=self.apply_default_affinity,
#     569     pod_type="worker",
#     570 )
#
# ValueError: Worker pod specification not provided. See KubeCluster docstring for ways to specify workers

# %%
with joblib.parallel_background()

# %% [markdown]
# # SGD classifier

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
# read in csv
df = pd.read_csv('data/training_25_features.csv')
print('-->DATA LOADED')
# train-test split
for i in range(23):
    df[df.columns[i]] = df[df.columns[i]].astype('float64')
X = df.drop(columns='ritmi')
y = df['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)
print('-->DATA SPLIT DONE')
print('-->MODEL TRAINING')
fitmodel = linear_model.SGDClassifier(n_jobs=10, max_iter = 1000, tol=1e-3,penalty = "elasticnet", verbose=True)
fitmodel.fit(X_train, y_train)
import pickle as pkl
print('-->SAVING MODEL')
pkl.dump(fitmodel, open('ECG&patient_SGD.pkl', 'wb'))
print('-->MODEL SAVED')
print('-->Testing model on test dataset')
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# -->DATA LOADED
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 12>()
#      10 X = df.drop(columns='ritmi')
#      11 y = df['ritmi']
# ---> 12 X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)
#      13 print('-->DATA SPLIT DONE')
#      14 print('-->MODEL TRAINING')
#
# NameError: name 'train_test_split' is not defined

# %%
loaded_model = pickle.load(open("ECG&patient_SGD.pkl", 'rb'))
print('-->Testing model on test dataset')
y_pred = loaded_model.predict(X_test)
print(classification_report(y_test, y_pred))
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
# -->Testing model on test dataset
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.50      0.43    335792
#          1.0       0.43      0.49      0.45    267846
#          2.0       0.62      0.43      0.51    476156
#
#     accuracy                           0.47   1079794
#    macro avg       0.48      0.47      0.47   1079794
# weighted avg       0.50      0.47      0.47   1079794
#
# ACCURACY: 0.4678114529252802
# MEAN ABS ERROR: 0.773654048827832

# %%
from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_auc_score
import parfit.parfit as pf

parameters = {
    'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3], # learning rate
    'loss': ['log'], # logistic regression,
    'penalty': ['l2'],
    'n_jobs': [-1]
}

fitmodel = GridSearchCV(SGDClassifier(), param_grid=parameters, cv=5, refit=True, scoring="accuracy", n_jobs=-1, verbose=True)
fitmodel.fit(X_train, y_train)

print(fitmodel.best_estimator_, fitmodel.best_params_, fitmodel.best_score_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\ashwi\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# SGDClassifier(alpha=0.001, loss='log', n_jobs=-1) {'alpha': 0.001, 'loss': 'log', 'n_jobs': -1, 'penalty': 'l2'} 0.4686437156597691

# %%
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.36      0.37    335792
#          1.0       0.50      0.25      0.34    267846
#          2.0       0.51      0.67      0.58    476156
#
#     accuracy                           0.47   1079794
#    macro avg       0.46      0.43      0.43   1079794
# weighted avg       0.47      0.47      0.45   1079794

# %%
dfecg = df[['I', 'II', 'III', 'aVF', 'aVR', 'aVL', 'V1', 'V2', 'V3', 'V4', 'V5','V6','ritmi']]
dfecg
# Out:
#              I     II    III    aVF    aVR    aVL     V1     V2     V3     V4  \
# 0       -0.005  0.135  0.140 -0.065 -0.073  0.137 -0.125 -0.090 -0.110 -0.210
# 1       -0.005  0.135  0.140 -0.065 -0.073  0.137 -0.125 -0.090 -0.110 -0.211
# 2       -0.005  0.131  0.136 -0.063 -0.070  0.133 -0.125 -0.082 -0.102 -0.190
# 3       -0.005  0.130  0.135 -0.063 -0.070  0.132 -0.122 -0.077 -0.094 -0.172
# 4       -0.005  0.128  0.133 -0.062 -0.069  0.130 -0.119 -0.071 -0.084 -0.157
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4319171  0.010  0.170  0.160 -0.090 -0.075  0.165  0.155  0.365  0.230  0.030
# 4319172  0.014  0.174  0.160 -0.094 -0.073  0.167  0.155  0.368  0.245  0.029
# 4319173  0.016  0.176  0.160 -0.096 -0.073  0.167  0.155  0.383  0.261  0.040
# 4319174  0.014  0.174  0.160 -0.094 -0.073  0.167  0.155  0.406  0.282  0.059
# 4319175  0.016  0.176  0.160 -0.096 -0.072  0.168  0.156  0.424  0.304  0.072
#
#             V5     V6  ritmi
# 0       -0.145 -0.080    2.0
# 1       -0.146 -0.080    2.0
# 2       -0.129 -0.072    2.0
# 3       -0.116 -0.067    2.0
# 4       -0.102 -0.061    2.0
# ...        ...    ...    ...
# 4319171 -0.065 -0.060    0.0
# 4319172 -0.057 -0.056    0.0
# 4319173 -0.052 -0.055    0.0
# 4319174 -0.046 -0.053    0.0
# 4319175 -0.039 -0.050    0.0
#
# [4319176 rows x 13 columns]

# %%
X = dfecg.drop(columns='ritmi')
y = dfecg['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)

# %%
parameters = {
    'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3], # learning rate
    'loss': ['log'], # logistic regression,
    'penalty': ['l2'],
    'n_jobs': [-1]
}

fitmodel = SGDClassifier(n_jobs=10, max_iter = 1000, tol=1e-3,penalty = "elasticnet", verbose=True)
fitmodel.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# -- Epoch 1
# -- Epoch 1
# -- Epoch 1
# Norm: 4.49, NNZs: 0, Bias: -0.994884, T: 3239382, Avg. loss: 0.634024
# Total training time: 1.48 seconds.
# -- Epoch 2
# Norm: 4.49, NNZs: 1, Bias: -1.000086, T: 3239382, Avg. loss: 0.502812
# Total training time: 1.66 seconds.
# -- Epoch 2
# Norm: 5.22, NNZs: 3, Bias: -0.998877, T: 3239382, Avg. loss: 0.895321
# Total training time: 1.70 seconds.
# -- Epoch 2
# Norm: 3.23, NNZs: 1, Bias: -0.998626, T: 6478764, Avg. loss: 0.624146
# Total training time: 2.80 seconds.
# -- Epoch 3
# Norm: 3.20, NNZs: 1, Bias: -1.001576, T: 6478764, Avg. loss: 0.494891
# Total training time: 3.29 seconds.
# -- Epoch 3
# Norm: 3.75, NNZs: 2, Bias: -0.995519, T: 6478764, Avg. loss: 0.883552
# Total training time: 3.30 seconds.
# -- Epoch 3
# Norm: 2.65, NNZs: 2, Bias: -0.998968, T: 9718146, Avg. loss: 0.623808
# Total training time: 4.20 seconds.
# -- Epoch 4
# Norm: 2.62, NNZs: 2, Bias: -1.000019, T: 9718146, Avg. loss: 0.494644
# Total training time: 4.92 seconds.
# -- Epoch 4
# Norm: 3.07, NNZs: 1, Bias: -0.997558, T: 9718146, Avg. loss: 0.883065
# Total training time: 4.98 seconds.
# -- Epoch 4
# Norm: 2.30, NNZs: 2, Bias: -0.996901, T: 12957528, Avg. loss: 0.623671
# Total training time: 5.58 seconds.
# -- Epoch 5
# Norm: 2.27, NNZs: 0, Bias: -1.000016, T: 12957528, Avg. loss: 0.494542
# Total training time: 6.48 seconds.
# -- Epoch 5
# Norm: 2.67, NNZs: 3, Bias: -0.998911, T: 12957528, Avg. loss: 0.882861
# Total training time: 6.63 seconds.
# -- Epoch 5
# Norm: 2.05, NNZs: 1, Bias: -1.000603, T: 16196910, Avg. loss: 0.623595
# Total training time: 6.92 seconds.
# -- Epoch 6
# Norm: 2.04, NNZs: 0, Bias: -1.000011, T: 16196910, Avg. loss: 0.494486
# Total training time: 8.08 seconds.
# -- Epoch 6
# Norm: 2.40, NNZs: 3, Bias: -0.996162, T: 16196910, Avg. loss: 0.882752
# Total training time: 8.26 seconds.
# -- Epoch 6
# Norm: 1.88, NNZs: 2, Bias: -1.000499, T: 19436292, Avg. loss: 0.623548
# Total training time: 8.33 seconds.
# -- Epoch 7
# Norm: 1.86, NNZs: 2, Bias: -1.000009, T: 19436292, Avg. loss: 0.494450
# Total training time: 9.68 seconds.
# -- Epoch 7
# Norm: 1.74, NNZs: 2, Bias: -1.000426, T: 22675674, Avg. loss: 0.623515
# Total training time: 9.70 seconds.
# Convergence after 7 epochs took 9.70 seconds
# Norm: 2.19, NNZs: 2, Bias: -0.999545, T: 19436292, Avg. loss: 0.882682
# Total training time: 9.88 seconds.
# -- Epoch 7
# Norm: 1.72, NNZs: 1, Bias: -1.000448, T: 22675674, Avg. loss: 0.494426
# Total training time: 10.98 seconds.
# Convergence after 7 epochs took 10.98 seconds
# Norm: 2.03, NNZs: 2, Bias: -0.998483, T: 22675674, Avg. loss: 0.882633
# Total training time: 11.28 seconds.
# Convergence after 7 epochs took 11.28 seconds
# [Parallel(n_jobs=10)]: Done   3 out of   3 | elapsed:   11.2s finished
# SGDClassifier(n_jobs=10, penalty='elasticnet', verbose=True)

# %%
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.00      0.01    335792
#          1.0       0.23      0.05      0.08    267846
#          2.0       0.44      0.94      0.60    476156
#
#     accuracy                           0.43   1079794
#    macro avg       0.28      0.33      0.23   1079794
# weighted avg       0.31      0.43      0.29   1079794
#
# ACCURACY: 0.4259951435181155
# MEAN ABS ERROR: 0.8716477402171154

# %% [markdown]
# # Decision Tree

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import classification_report
# read in csv
df = pd.read_csv('data/training_25_features.csv')
print('-->DATA LOADED')
# train-test split
for i in range(23):
    df[df.columns[i]] = df[df.columns[i]].astype('float64')
X = df.drop(columns='ritmi')
y = df['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)
print('-->DATA SPLIT DONE')
print('-->MODEL TRAINING')
'''parameters = { 
    'criterion':['gini','entropy']
}'''
'''fitmodel = GridSearchCV(
    DecisionTreeClassifier(), 
    param_grid=parameters,
    refit=True, scoring="accuracy", 
    n_jobs=10, 
    verbose=10
)'''
fitmodel = DecisionTreeClassifier()
fitmodel.fit(X_train, y_train)
import pickle as pkl
print('-->SAVING MODEL')
pkl.dump(fitmodel, open('ECG&patient_DT.pkl', 'wb'))
print('-->MODEL SAVED')
print('-->Testing model on test dataset')
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# -->DATA LOADED
# -->DATA SPLIT DONE
# -->MODEL TRAINING
# -->SAVING MODEL
# -->MODEL SAVED
# -->Testing model on test dataset
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99    335792
#          1.0       0.97      0.98      0.97    267846
#          2.0       0.98      0.98      0.98    476156
#
#     accuracy                           0.98   1079794
#    macro avg       0.98      0.98      0.98   1079794
# weighted avg       0.98      0.98      0.98   1079794

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
# ACCURACY: 0.9821039939099495
# MEAN ABS ERROR: 0.022980309207126546

# %%
dfecg = df[['I', 'II', 'III', 'aVF', 'aVR', 'aVL', 'V1', 'V2', 'V3', 'V4', 'V5','V6','ritmi']]
X = dfecg.drop(columns='ritmi')
y = dfecg['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)

# %%
fitmodel = DecisionTreeClassifier()
fitmodel.fit(X_train, y_train)
import pickle as pkl
print('-->SAVING MODEL')
pkl.dump(fitmodel, open('ECG_DT.pkl', 'wb'))
print('-->MODEL SAVED')
print('-->Testing model on test dataset')
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
# -->SAVING MODEL
# -->MODEL SAVED
# -->Testing model on test dataset
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.79      0.79    335792
#          1.0       0.76      0.76      0.76    267846
#          2.0       0.82      0.81      0.82    476156
#
#     accuracy                           0.79   1079794
#    macro avg       0.79      0.79      0.79   1079794
# weighted avg       0.79      0.79      0.79   1079794
#
# ACCURACY: 0.7928558595435796
# MEAN ABS ERROR: 0.29506646638155054

# %% [markdown]
# # Random Forest

# %%
dfecg = df[['I', 'II', 'III', 'aVF', 'aVR', 'aVL', 'V1', 'V2', 'V3', 'V4', 'V5','V6','ritmi']]
X = dfecg.drop(columns='ritmi')
y = dfecg['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)

# %%
from sklearn.ensemble import RandomForestClassifier
fitmodel = RandomForestClassifier()
fitmodel.fit(X_train, y_train)
import pickle as pkl
print('-->SAVING MODEL')
pkl.dump(fitmodel, open('ECG_RF.pkl', 'wb'))
print('-->MODEL SAVED')
print('-->Testing model on test dataset')
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
# -->SAVING MODEL
# -->MODEL SAVED
# -->Testing model on test dataset
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89    335792
#          1.0       0.90      0.85      0.87    267846
#          2.0       0.87      0.93      0.90    476156
#
#     accuracy                           0.89   1079794
#    macro avg       0.90      0.88      0.89   1079794
# weighted avg       0.89      0.89      0.89   1079794
#
# ACCURACY: 0.8907365664191503
# MEAN ABS ERROR: 0.15806811299192253

# %%
X = df.drop(columns='ritmi')
y = df['ritmi']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size = 0.25, random_state = 1234)

# %%
from sklearn.ensemble import RandomForestClassifier
fitmodel = RandomForestClassifier()
fitmodel.fit(X_train, y_train)
import pickle as pkl
print('-->SAVING MODEL')
pkl.dump(fitmodel, open('ECG&patient_RF.pkl', 'wb'))
print('-->MODEL SAVED')
print('-->Testing model on test dataset')
y_pred = fitmodel.predict(X_test)
print(classification_report(y_test, y_pred))
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
# -->SAVING MODEL
# -->MODEL SAVED
# -->Testing model on test dataset
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99    335792
#          1.0       0.98      0.98      0.98    267846
#          2.0       0.99      0.99      0.99    476156
#
#     accuracy                           0.99   1079794
#    macro avg       0.99      0.99      0.99   1079794
# weighted avg       0.99      0.99      0.99   1079794
#
# ACCURACY: 0.9871049477955981
# MEAN ABS ERROR: 0.015805792586363696

# %% [markdown]
# # KNN

# %%
import pickle as pkl
model = pkl.load(open("ECG&patient_KNN.pkl", 'rb'))

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error
print('ACCURACY:',accuracy_score(y_test, y_pred),'\nMEAN ABS ERROR:',mean_absolute_error(y_test, y_pred))
# Out:
# ACCURACY: 0.9763121484283114
# MEAN ABS ERROR: 0.03120780445158984
